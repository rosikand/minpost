# %% [markdown]
# # Getting Started with `minpost`
#
# This notebook shows a minimal workflow to set up logging, prepare a config, and run a simple training loop using `minpost` components.
#
# If you haven't installed the project locally:
#
# ```bash
# pip install -e ..
# ```

# %%
# Imports
from minpost import Trainer, DataLoader
from minpost.utils import setup_logging

# Configure logging for the notebook
setup_logging()

# %%
# Example configuration
config = {
    "learning_rate": 2e-5,
    "batch_size": 8,
    "epochs": 3,
    "max_length": 512,
}
config

# %% [markdown]
# ## Load your model and data
#
# Replace the placeholders below with your actual model and dataset handling.

# %%
# TODO: Initialize your model here
# model = ...

# TODO: Prepare your dataset
# tokenizer = ...
# data_loader = DataLoader("path/to/data", tokenizer)
# train_dataset = data_loader.load()

# %%
# TODO: Train your model
# trainer = Trainer(model, config)
# trainer.train(train_dataset)

print("Notebook scaffold ready. Fill in model and dataset specifics.")
