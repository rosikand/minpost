# %% [markdown]
# # Post training an LLM for reasoning with GRPO in TRL - HF Tutorial
#
# We will be following along this tutorial from HF:
# https://huggingface.co/learn/cookbook/fine_tuning_llm_grpo_trl
#
# - Colab: https://colab.research.google.com/github/huggingface/cookbook/blob/main/notebooks/en/fine_tuning_llm_grpo_trl.ipynb

# %% [markdown]
# Notes:
#
# - will do PT on LLM with GRPO
# - We will load and eval on a math reasoning dataset
# - Then, we will implement a post-training pipeline with TRL's implementation of GRPO and fine-tune a base model on the dataset
# - Re-run the eval.

# %%
# %uv pip install  -U -q trl peft math_verify
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1. Load and inspect dataset
